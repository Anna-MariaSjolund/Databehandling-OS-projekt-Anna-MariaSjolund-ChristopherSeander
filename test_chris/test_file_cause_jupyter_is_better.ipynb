# %%
import pandas as pd
data = pd.read_csv("../Data/athlete_events.csv")

# %%
data2 = data.dropna(subset=["Medal"])
data2 = data2.drop_duplicates(subset=["Event", "Games", "Medal", "NOC"])
data2 = data2[data2["NOC"] == "USA"]
len(data2)
# Out:
# 2823

# %%
data3 = data[data["NOC"] == "USA"]
data3 = data3.dropna(subset=["Medal"])
data3 = data3.drop_duplicates(subset=["Event", "Games", "Medal"])
len(data3)
# Out:
# 2823

# %%
data4 = data.dropna(subset=["Medal"])
data4 = data4[data["NOC"] == "USA"]
data4 = data4.drop_duplicates(subset=["Event", "Games", "Medal"])
len(data4)
# Out:
# C:\Users\chris\AppData\Local\Temp/ipykernel_9232/167329702.py:2: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
# 2823

# %%
data.loc[205050]
# Out:
# ID                             102964
# Name      Ronda Jean Rousey (-Browne)
# Sex                                 F
# Age                              21.0
# Height                          170.0
# Weight                           70.0
# Team                    United States
# NOC                               USA
# Games                     2008 Summer
# Year                             2008
# Season                         Summer
# City                          Beijing
# Sport                            Judo
# Event       Judo Women's Middleweight
# Medal                          Bronze
# Name: 205050, dtype: object

# %%
data3[~data3.index.isin(data2.index)]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
data[data["Year"] == 2016 ][data["Event"] == "Swimming Men's 100 metres Butterfly"][data["Medal"].notna()]
# Out:
# C:\Users\chris\AppData\Local\Temp/ipykernel_9232/2474123658.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#             ID                       Name Sex   Age  Height  Weight  \
# 46722    24093             Lszl Cseh, Jr.   M  30.0   188.0    83.0
# 134053   67496  Chad Guy Bertrand le Clos   M  24.0   190.0    83.0
# 187913   94406    Michael Fred Phelps, II   M  31.0   193.0    91.0
# 213955  107436     Joseph Isaac Schooling   M  21.0   184.0    74.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 46722         Hungary  HUN  2016 Summer  2016  Summer  Rio de Janeiro
# 134053   South Africa  RSA  2016 Summer  2016  Summer  Rio de Janeiro
# 187913  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 213955      Singapore  SGP  2016 Summer  2016  Summer  Rio de Janeiro
#
#            Sport                                Event   Medal
# 46722   Swimming  Swimming Men's 100 metres Butterfly  Silver
# 134053  Swimming  Swimming Men's 100 metres Butterfly  Silver
# 187913  Swimming  Swimming Men's 100 metres Butterfly  Silver
# 213955  Swimming  Swimming Men's 100 metres Butterfly    Gold

# %%
sports = data[data["Sport"].isin(["Alpine Skiing", "Basketball", "Gymnastics", "Rhythmic Gymnastics"])]
running_events = ["Athletics Women's 100 metres", "Athletics Women's 200 metres", "Athletics Women's 400 metres",  "Athletics Women's 800 metres", "Athletics Women's 1,500 metres", 
"Athletics Women's 3,000 metres", "Athletics Women's 5,000 metres", "Athletics Women's 10,000 metres",  "Athletics Women's Marathon", "Athletics Men's 60 metres", 
"Athletics Men's 100 metres", "Athletics Men's 200 metres", "Athletics Men's 400 metres", "Athletics Men's 800 metres", "Athletics Men's 1,500 metres", 
"Athletics Men's 5,000 metres", "Athletics Men's 10,000 metres", "Athletics Men's Marathon"]
running = data[data["Event"].isin(running_events)]
sports = sports.append(running)
sports.reset_index(drop=True)
sports["Sport"].unique()
sports.loc[sports["Sport"] == "Athletics", "Sport"] = "Running"
sports
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 0            1                      A Dijiang   M  24.0   180.0    80.0
# 41          17        Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 42          17        Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 43          17        Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17        Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                            ...  ..   ...     ...     ...
# 271045  135544             Krzysztof Zwoliski   M  21.0   175.0    70.0
# 271052  135547  Viktoriya Viktorovna Zyabkina   F  19.0   174.0    62.0
# 271053  135547  Viktoriya Viktorovna Zyabkina   F  23.0   174.0    62.0
# 271054  135547  Viktoriya Viktorovna Zyabkina   F  23.0   174.0    62.0
# 271100  135561                  Frantiek Zyka   M  26.0     NaN     NaN
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 41             Finland  FIN  1948 Summer  1948  Summer          London
# 42             Finland  FIN  1948 Summer  1948  Summer          London
# 43             Finland  FIN  1948 Summer  1948  Summer          London
# 44             Finland  FIN  1948 Summer  1948  Summer          London
# ...                ...  ...          ...   ...     ...             ...
# 271045          Poland  POL  1980 Summer  1980  Summer          Moskva
# 271052      Kazakhstan  KAZ  2012 Summer  2012  Summer          London
# 271053      Kazakhstan  KAZ  2016 Summer  2016  Summer  Rio de Janeiro
# 271054      Kazakhstan  KAZ  2016 Summer  2016  Summer  Rio de Janeiro
# 271100  Czechoslovakia  TCH  1928 Summer  1928  Summer       Amsterdam
#
#              Sport                                   Event   Medal
# 0       Basketball             Basketball Men's Basketball     NaN
# 41      Gymnastics  Gymnastics Men's Individual All-Around  Bronze
# 42      Gymnastics        Gymnastics Men's Team All-Around    Gold
# 43      Gymnastics         Gymnastics Men's Floor Exercise     NaN
# 44      Gymnastics            Gymnastics Men's Horse Vault    Gold
# ...            ...                                     ...     ...
# 271045     Running              Athletics Men's 100 metres     NaN
# 271052     Running            Athletics Women's 200 metres     NaN
# 271053     Running            Athletics Women's 100 metres     NaN
# 271054     Running            Athletics Women's 200 metres     NaN
# 271100     Running                Athletics Men's Marathon     NaN
#
# [56769 rows x 15 columns]

# %%
data["Sport"].sort_values().unique()
# Out:
# array(['Aeronautics', 'Alpine Skiing', 'Alpinism', 'Archery',
#        'Art Competitions', 'Athletics', 'Badminton', 'Baseball',
#        'Basketball', 'Basque Pelota', 'Beach Volleyball', 'Biathlon',
#        'Bobsleigh', 'Boxing', 'Canoeing', 'Cricket', 'Croquet',
#        'Cross Country Skiing', 'Curling', 'Cycling', 'Diving',
#        'Equestrianism', 'Fencing', 'Figure Skating', 'Football',
#        'Freestyle Skiing', 'Golf', 'Gymnastics', 'Handball', 'Hockey',
#        'Ice Hockey', 'Jeu De Paume', 'Judo', 'Lacrosse', 'Luge',
#        'Military Ski Patrol', 'Modern Pentathlon', 'Motorboating',
#        'Nordic Combined', 'Polo', 'Racquets', 'Rhythmic Gymnastics',
#        'Roque', 'Rowing', 'Rugby', 'Rugby Sevens', 'Sailing', 'Shooting',
#        'Short Track Speed Skating', 'Skeleton', 'Ski Jumping',
#        'Snowboarding', 'Softball', 'Speed Skating', 'Swimming',
#        'Synchronized Swimming', 'Table Tennis', 'Taekwondo', 'Tennis',
#        'Trampolining', 'Triathlon', 'Tug-Of-War', 'Volleyball',
#        'Water Polo', 'Weightlifting', 'Wrestling'], dtype=object)

# %%
test = data[data["Sport"] == "Basketball"].dropna(subset=["Medal"])

# %%
test = test.drop_duplicates(subset=["Event", "Games", "Medal", "NOC"])
test["Medal"].groupby(test["NOC"]).count().sort_values(ascending=False).head(10)
# Out:
# NOC
# USA    28
# URS    12
# YUG     7
# AUS     5
# BRA     5
# ESP     5
# RUS     3
# LTU     3
# FRA     3
# URU     2
# Name: Medal, dtype: int64

# %%
basket = data[data["Sport"] == "Basketball"]
basket
m_data = basket[basket["Sex"] == "M"]
m_data = m_data["Sex"].groupby(basket["Year"]).count()
f_data = basket[basket["Sex"] == "F"]
f_data = f_data["Sex"].groupby(basket["Year"]).count()
f_data
gender = pd.DataFrame(dict(m = m_data, f = f_data))
import plotly_express as px
px.line(gender)

# %%
age = data[data["Sport"] == "Basketball"]

# %%
age = age["Age"].value_counts()

# %%
age
import plotly.figure_factory as ff
age_data_m = data[data["Sport"] == "Basketball"]
age_data_m = pd.DataFrame(age_data_m["Age"][data["Sex"] == "M"])
age_data_m = age_data_m[age_data_m["Age"].notna()]

age_data_f = data[data["Sport"] == "Basketball"]
age_data_f = pd.DataFrame(age_data_f["Age"][data["Sex"] == "F"])
age_data_f = age_data_f[age_data_f["Age"].notna()]

age_data = [age_data_m["Age"], age_data_f["Age"]]

colors = ['midnightblue', 'magenta']
ff.create_distplot(age_data, ["Men", "Women"], colors=colors, curve_type="normal")

# %%
from load_data import SportStatistics
test = SportStatistics()
asd = test.age("Running")
ff.create_distplot(asd, ["Men", "Women"])

# %%
height_data = test.sport_and_year("Basketball")
height_gold = height_data[height_data["Medal"].isna()]["Height"].mean()

height_data
# Out:
#            ID                                Name Sex   Age  Height  Weight  \
# 0           1                           A Dijiang   M  24.0   180.0    80.0
# 45         69                   Tamara Abalde Daz   F  19.0   185.0    72.0
# 47        124               Youssef Mohamed Abbas   M  31.0     NaN     NaN
# 50        136                    Alessandro Abbio   M  29.0   195.0    85.0
# 59        192  Ahmed El-Sayed Abdel Hamid Mobarak   M  25.0   189.0    85.0
# ...       ...                                 ...  ..   ...     ...     ...
# 40661  135401                  Eurelijus ukauskas   M  30.0   218.0   115.0
# 40662  135402                  Mindaugas ukauskas   M  20.0   201.0   100.0
# 40663  135402                  Mindaugas ukauskas   M  28.0   201.0   100.0
# 40726  135530                      Philip Zwiener   M  23.0   202.0    98.0
# 40729  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#             Team  NOC        Games  Year  Season            City       Sport  \
# 0          China  CHN  1992 Summer  1992  Summer       Barcelona  Basketball
# 45         Spain  ESP  2008 Summer  2008  Summer         Beijing  Basketball
# 47         Egypt  EGY  1952 Summer  1952  Summer        Helsinki  Basketball
# 50         Italy  ITA  2000 Summer  2000  Summer          Sydney  Basketball
# 59         Egypt  EGY  1972 Summer  1972  Summer          Munich  Basketball
# ...          ...  ...          ...   ...     ...             ...         ...
# 40661  Lithuania  LTU  2004 Summer  2004  Summer          Athina  Basketball
# 40662  Lithuania  LTU  1996 Summer  1996  Summer         Atlanta  Basketball
# 40663  Lithuania  LTU  2004 Summer  2004  Summer          Athina  Basketball
# 40726    Germany  GER  2008 Summer  2008  Summer         Beijing  Basketball
# 40729    Belarus  BLR  2016 Summer  2016  Summer  Rio de Janeiro  Basketball
#
#                                Event   Medal
# 0        Basketball Men's Basketball     NaN
# 45     Basketball Women's Basketball     NaN
# 47       Basketball Men's Basketball     NaN
# 50       Basketball Men's Basketball     NaN
# 59       Basketball Men's Basketball     NaN
# ...                              ...     ...
# 40661    Basketball Men's Basketball     NaN
# 40662    Basketball Men's Basketball  Bronze
# 40663    Basketball Men's Basketball     NaN
# 40726    Basketball Men's Basketball     NaN
# 40729  Basketball Women's Basketball     NaN
#
# [4536 rows x 15 columns]

# %%
        height_data = test.sport_and_year("Basketball")
        mean_hight_data = {}

        for medal in ["Gold", "Silver", "Bronze"]:
            mean_hight_data[medal] = height_data[height_data["Medal"] == medal]["Height"].mean()
        mean_hight_data["No medal"] = height_data[height_data["Medal"].isna()]["Height"].mean()
        mean_hight_data = pd.DataFrame(mean_hight_data.items(), columns=["Medal", "Mean height"])

# %%
mean_hight_data
# Out:
#       Medal  Mean height
# 0      Gold   192.873626
# 1    Silver   191.609467
# 2    Bronze   191.385093
# 3  No medal   190.469023

# %%
px.bar(mean_hight_data, x="Medal", y="Mean height")
